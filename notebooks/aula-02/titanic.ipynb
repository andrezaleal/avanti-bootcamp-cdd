# %%
# carregar biblioteca 
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Leitura do conjunto de dados

# %% [markdown]
# ### pinguins

# %%
df_titanic = sns.load_dataset('titanic')
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# - Dicionário de Dados

# %%
dicionario_titanic = pd.DataFrame([
    {
        "Nome": "survived",
        "Descricao":"Indica se o passageiro sobreviveu",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
    {
        "Nome": "pclass",
        "Descricao":"Classe da passagem",
        "Tipo": "Qualitativo",
        "Subtipo": "Ordem",
    },
    {
        "Nome": "sex",
        "Descricao":"Indica o sexo do passageiro",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
    {
        "Nome": "age",
        "Descricao":"Indica a idade do passageiro",
        "Tipo": "Quantitativo",
        "Subtipo": "Discreto",
    },
    {
        "Nome": "sibsp",
        "Descricao":"Numero de irmãos/cônjuges a bordo",
        "Tipo": "Quantitativo",
        "Subtipo": "Discreto",
    },
    {
        "Nome": "parch",
        "Descricao":"Número de pais/filhos a bordo.",
        "Tipo": "Quantitativo",
        "Subtipo": "Discreto",
    },
    {
        "Nome": "fare",
        "Descricao":"Tarifa paga pelo passageiro",
        "Tipo": "Quantitativo",
        "Subtipo": "Contínuo",
    },
    {
        "Nome": "embarked",
        "Descricao":"Porta de embarque do passageiro",
        "Tipo": "Qualitativo",
        "Subtipo": "Ordem",
    },
    {
        "Nome": "class",
        "Descricao":"Refere-se à classe da passagem do passageiro",
        "Tipo": "Qualitativo",
        "Subtipo": "Ordem",
    },
    {
        "Nome": "who",
        "Descricao":"Indica o gênero e idade do passageiro",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
    {
        "Nome": "adult_male",
        "Descricao":"Indica se o passageiro é adulto e do sexo masculino",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
     {
        "Nome": "deck",
        "Descricao":" Representa o deck em que a cabine do passageiro estava localizada.",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
     {
        "Nome": "embark_town",
        "Descricao":"Refere-se à cidade de embarque do passageiro",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
     {
        "Nome": "alive",
        "Descricao":"Indica se o passageiro sobreviveu.",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },
     {
        "Nome": "alone",
        "Descricao":"Indica se o passageiro estava viajando sozinho",
        "Tipo": "Qualitativo",
        "Subtipo": "Nominal",
    },

])

dicionario_titanic
# Out:
#            Nome                                          Descricao  \
# 0      survived                  Indica se o passageiro sobreviveu
# 1        pclass                                 Classe da passagem
# 2           sex                        Indica o sexo do passageiro
# 3           age                       Indica a idade do passageiro
# 4         sibsp                  Numero de irmãos/cônjuges a bordo
# 5         parch                     Número de pais/filhos a bordo.
# 6          fare                        Tarifa paga pelo passageiro
# 7      embarked                    Porta de embarque do passageiro
# 8         class       Refere-se à classe da passagem do passageiro
# 9           who              Indica o gênero e idade do passageiro
# 10   adult_male  Indica se o passageiro é adulto e do sexo masc...
# 11         deck   Representa o deck em que a cabine do passagei...
# 12  embark_town       Refere-se à cidade de embarque do passageiro
# 13        alive                 Indica se o passageiro sobreviveu.
# 14        alone     Indica se o passageiro estava viajando sozinho
#
#             Tipo   Subtipo
# 0    Qualitativo   Nominal
# 1    Qualitativo     Ordem
# 2    Qualitativo   Nominal
# 3   Quantitativo  Discreto
# 4   Quantitativo  Discreto
# 5   Quantitativo  Discreto
# 6   Quantitativo  Contínuo
# 7    Qualitativo     Ordem
# 8    Qualitativo     Ordem
# 9    Qualitativo   Nominal
# 10   Qualitativo   Nominal
# 11   Qualitativo   Nominal
# 12   Qualitativo   Nominal
# 13   Qualitativo   Nominal
# 14   Qualitativo   Nominal

# %% [markdown]
# - Estatística de tendência central e dispersão

# %%
#Funções que calculam a moda, o intervalo e o intervalo interquartil

#Função para calcular a moda
def mode(column):
    mode = column.mode()
    if not mode.empty: 
        return mode.iloc[0]
    else:
        return None
    
#Função para calcular o intervalo
def intervalo(column):
    inter = column.max() - column.min()
    return inter

#Função para calcular o intervalo interquartil
def intervalo_interquartil(column):
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    iqr = q3 - q1
    return iqr

# %%
# Lista para renomear o  titulo das colunas para melhor compreensão
titulo_tabela = {
    'mean': 'Média',
    'median': 'Mediana',
    'std': 'Desvio Padrão',
    'var': 'Variância',
    'mode': 'Moda',
    'intervalo': 'Intervalo',
    'intervalo_interquartil': 'Intervalo Interquartil'
}

# %%
# Filtrar apenas as colunas numéricas
numeric_columns  = df_titanic.select_dtypes(include=['number']).drop(columns=['survived', 'pclass'])

# Adicionado o calculo das medidas de tendência central e dispersão
tendencia_central_e_dispersao_values =  numeric_columns .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])

#Renomeando as colunas
tendencia_central_e_dispersao_values.rename(titulo_tabela, inplace=True)

#Imprimindo o DataFrame
tendencia_central_e_dispersao_values
# Out:
#                                age     sibsp     parch         fare
# Média                    29.699118  0.523008  0.381594    32.204208
# Mediana                  28.000000  0.000000  0.000000    14.454200
# Desvio Padrão            14.526497  1.102743  0.806057    49.693429
# Variância               211.019125  1.216043  0.649728  2469.436846
# Moda                     24.000000  0.000000  0.000000     8.050000
# Intervalo                79.580000  8.000000  6.000000   512.329200
# Intervalo Interquartil   17.875000  1.000000  0.000000    23.089600

# %% [markdown]
# - Calculo estastítica de forma separada para cada variável categórica

# %%
# Filtrar apenas as colunas numéricas
numeric_columns  = df_titanic.select_dtypes(include=['number']).drop(columns=['survived', 'pclass']).columns

# %% [markdown]
#     - Por classe da passagem

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_class = (
    df_titanic
    .groupby('class')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_class = values_by_class.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_class
# Out:
#               age                                                    \
#             Média Mediana Desvio Padrão   Variância  Moda Intervalo
# class
# First   38.233441    37.0     14.802856  219.124543  35.0     79.08
# Second  29.877630    29.0     14.001077  196.030152  24.0     69.33
# Third   25.140620    24.0     12.495398  156.134976  22.0     73.58
#
#                                   sibsp                        ... parch  \
#        Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# class                                                          ...
# First                    22.0  0.416667     0.0      0.611898  ...     0
# Second                   13.0  0.402174     0.0      0.601633  ...     0
# Third                    14.0  0.615071     0.0      1.374883  ...     0
#
#                                               fare                         \
#        Intervalo Intervalo Interquartil      Média  Mediana Desvio Padrão
# class
# First          4                    0.0  84.154687  60.2875     78.380373
# Second         3                    1.0  20.662183  14.2500     13.417399
# Third          6                    0.0  13.675550   8.0500     11.778142
#
#
#           Variância   Moda Intervalo Intervalo Interquartil
# class
# First   6143.482816  26.55  512.3292               62.57605
# Second   180.026589  13.00   73.5000               13.00000
# Third    138.724622   8.05   69.5500                7.75000
#
# [3 rows x 28 columns]

# %% [markdown]
#     - Por gênero

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_sex = (
    df_titanic
    .groupby('sex')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_sex = values_by_sex.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_sex
# Out:
#               age                                                    \
#             Média Mediana Desvio Padrão   Variância  Moda Intervalo
# sex
# female  27.915709    27.0     14.110146  199.096233  24.0     62.25
# male    30.726645    29.0     14.678201  215.449579  19.0     79.58
#
#                                   sibsp                        ... parch  \
#        Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# sex                                                            ...
# female                   19.0  0.694268     0.0      1.156520  ...     0
# male                     18.0  0.429809     0.0      1.061811  ...     0
#
#                                               fare                        \
#        Intervalo Intervalo Interquartil      Média Mediana Desvio Padrão
# sex
# female         6                    1.0  44.479818    23.0     57.997698
# male           5                    0.0  25.523893    10.5     43.138263
#
#
#           Variância  Moda Intervalo Intervalo Interquartil
# sex
# female  3363.732930  7.75  505.5792              42.928125
# male    1860.909702  8.05  512.3292              18.654200
#
# [2 rows x 28 columns]

# %% [markdown]
#     - Por gênero e idade

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_who = (
    df_titanic
    .groupby('who')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_who = values_by_who.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_who
# Out:
#              age                                                    \
#            Média Mediana Desvio Padrão   Variância  Moda Intervalo
# who
# child   6.369518     5.0      4.729063   22.364041   2.0     14.58
# man    33.173123    30.0     12.906908  166.588281  19.0     64.00
# woman  32.000000    30.0     11.495441  132.145161  24.0     47.00
#
#                                  sibsp                        ... parch  \
#       Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# who                                                           ...
# child                    7.5  1.734940     1.0      1.638592  ...     1
# man                     17.0  0.296089     0.0      0.850726  ...     0
# woman                   16.0  0.601476     0.0      1.093685  ...     0
#
#                                              fare                        \
#       Intervalo Intervalo Interquartil      Média Mediana Desvio Padrão
# who
# child         2                    1.0  32.785795   26.25     33.466438
# man           5                    0.0  24.864182    9.50     44.021339
# woman         6                    1.0  46.570711   23.25     60.318995
#
#
#          Variância    Moda Intervalo Intervalo Interquartil
# who
# child  1120.002500  31.275  204.1125               16.29375
# man    1937.878308   8.050  512.3292               18.53330
# woman  3638.381145   7.750  505.5792               54.50000
#
# [3 rows x 28 columns]

# %% [markdown]
#     - Por porta de embarque

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_embarked = (
    df_titanic
    .groupby('embarked')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_embarked = values_by_embarked.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_embarked
# Out:
#                 age                                                    \
#               Média Mediana Desvio Padrão   Variância  Moda Intervalo
# embarked
# C         30.814769    29.0     15.434860  238.234892  24.0     70.58
# Q         28.089286    27.0     16.915396  286.130622  16.0     68.50
# S         29.445397    28.0     14.143192  200.029876  24.0     79.33
#
#                                     sibsp                        ... parch  \
#          Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# embarked                                                         ...
# C                         18.75  0.386905     0.0      0.557213  ...     0
# Q                         17.00  0.428571     0.0      0.979105  ...     0
# S                         17.00  0.571429     0.0      1.216600  ...     0
#
#                                                 fare                        \
#          Intervalo Intervalo Interquartil      Média Mediana Desvio Padrão
# embarked
# C                3                    1.0  59.954144   29.70     83.912994
# Q                5                    0.0  13.276030    7.75     14.188047
# S                6                    0.0  27.079812   13.00     35.887993
#
#
#             Variância    Moda Intervalo Intervalo Interquartil
# embarked
# C         7041.390607  7.2292  508.3167              64.802075
# Q          201.300677  7.7500   83.2500               7.750000
# S         1287.948067  8.0500  263.0000              19.850000
#
# [3 rows x 28 columns]

# %% [markdown]
#     - Por adulto do gênero masculino

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_adult_male = (
    df_titanic
    .groupby('adult_male')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_adult_male = values_by_adult_male.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_adult_male
# Out:
#                   age                                                    \
#                 Média Mediana Desvio Padrão   Variância  Moda Intervalo
# adult_male
# False       24.932458    24.0     15.275127  233.329505  24.0     62.58
# True        33.173123    30.0     12.906908  166.588281  19.0     64.00
#
#                                       sibsp                        ... parch  \
#            Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# adult_male                                                         ...
# False                        21.0  0.867232     0.0      1.330360  ...     0
# True                         17.0  0.296089     0.0      0.850726  ...     0
#
#                                                   fare                        \
#            Intervalo Intervalo Interquartil      Média Mediana Desvio Padrão
# adult_male
# False              6                    1.0  43.338655   24.15     55.473168
# True               5                    0.0  24.864182    9.50     44.021339
#
#
#               Variância   Moda Intervalo Intervalo Interquartil
# adult_male
# False       3077.272372  26.00  505.5792              39.291675
# True        1937.878308   8.05  512.3292              18.533300
#
# [2 rows x 28 columns]

# %% [markdown]
#     - Por passageiro que sobreviveram ou não

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_survived = (
    df_titanic
    .groupby('survived')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_survived = values_by_survived.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_survived
# Out:
#                 age                                                    \
#               Média Mediana Desvio Padrão   Variância  Moda Intervalo
# survived
# 0         30.626179    28.0     14.172110  200.848698  21.0     73.00
# 1         28.343690    28.0     14.950952  223.530965  24.0     79.58
#
#                                     sibsp                        ... parch  \
#          Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# survived                                                         ...
# 0                          18.0  0.553734     0.0      1.288399  ...     0
# 1                          17.0  0.473684     0.0      0.708688  ...     0
#
#                                                 fare                        \
#          Intervalo Intervalo Interquartil      Média Mediana Desvio Padrão
# survived
# 0                6                    0.0  22.117887    10.5     31.388207
# 1                5                    1.0  48.395408    26.0     66.596998
#
#
#             Variância   Moda Intervalo Intervalo Interquartil
# survived
# 0          985.219509   8.05  263.0000                18.1458
# 1         4435.160158  13.00  512.3292                44.5250
#
# [2 rows x 28 columns]

# %% [markdown]
#     - Por passgeiros que viajavam sozinhos ou não

# %%
# Adicionado o calculo das medidas de tendência central e dispersão
values_by_alone = (
    df_titanic
    .groupby('alone')[numeric_columns]
    .agg(['mean', 'median','std', 'var', mode, intervalo, intervalo_interquartil])
)

#Renomeando as colunas
values_by_alone = values_by_alone.rename(columns = titulo_tabela)

#Imprimindo o DataFrame
values_by_alone
# Out:
#              age                                                    \
#            Média Mediana Desvio Padrão   Variância  Moda Intervalo
# alone
# False  26.413452    26.0     15.834923  250.744797  18.0     69.58
# True   32.220297    29.5     12.899871  166.406684  22.0     75.00
#
#                                  sibsp                        ... parch  \
#       Intervalo Interquartil     Média Mediana Desvio Padrão  ...  Moda
# alone                                                         ...
# False                   21.0  1.316384     1.0      1.420774  ...     0
# True                    17.0  0.000000     0.0      0.000000  ...     0
#
#                                              fare                         \
#       Intervalo Intervalo Interquartil      Média  Mediana Desvio Padrão
# alone
# False         6                    2.0  48.832275  27.7500     55.307615
# True          0                    0.0  21.242689   8.1375     42.223510
#
#
#          Variância   Moda Intervalo Intervalo Interquartil
# alone
# False  3058.932321  26.00  505.8334                41.0448
# True   1782.824830   8.05  512.3292                 7.2250
#
# [2 rows x 28 columns]
